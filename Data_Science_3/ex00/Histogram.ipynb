# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import math

# %% [markdown]
# # Test Knight

# %%
data = pd.read_csv("subject/Test_knight.csv")
data.head()
# Out:
#    Sensitivity  Hability  Strength   Power  Agility  Dexterity  Awareness  \
# 0        11.42     20.38     77.58   386.1  0.14250    0.28390    0.24140
# 1        18.25     19.98    119.60  1040.0  0.09463    0.10900    0.11270
# 2        14.68     20.13     94.74   684.5  0.09867    0.07200    0.07395
# 3        13.54     14.36     87.46   566.3  0.09779    0.08129    0.06664
# 4        15.34     14.26    102.50   704.4  0.10730    0.21350    0.20770
#
#    Prescience  Reactivity  Midi-chlorien  ...  Recovery  Evade   Stims  \
# 0     0.10520      0.2597        0.09744  ...     14.91  26.50   98.87
# 1     0.07400      0.1794        0.05742  ...     22.88  27.66  153.20
# 2     0.05259      0.1586        0.05922  ...     19.07  30.88  123.40
# 3     0.04781      0.1885        0.05766  ...     15.11  19.26   99.70
# 4     0.09756      0.2521        0.07032  ...     18.07  19.08  125.10
#
#    Sprint   Combo   Delay  Attunement  Empowered   Burst  Grasping
# ...

# %%
# Numero de bins y columnas totales del DataFrame
n_bins = 40
num_columns = len(data.columns)

# Definir el número de columnas por fila
cols_per_row = 5

# Calcular el número total de filas necesarias (redondeando hacia arriba)
num_rows = math.ceil(num_columns / cols_per_row)

# Crear una figura y una cuadrícula de subplots usando plt.subplots()
fig, axes = plt.subplots(num_rows, cols_per_row, figsize=(25, 25))
fig.tight_layout(pad=5.0)  # Ajustar espacio entre gráficos

# Iterar por cada columna del DataFrame y crear su respectivo histograma
for index, column in enumerate(data.columns):
    # Calcular la posición en la cuadrícula
    row = index // cols_per_row
    col = index % cols_per_row

    # Crear el histograma en la posición correspondiente
    ax = axes[row, col]
    ax.hist(data[column], bins=n_bins, color='#7fbf7f', label='Knight')
    ax.set_title(column)
    ax.legend(loc="upper right")

    # Ajustar el eje y para que los ticks vayan de 5 en 5, comenzando desde 0
    max_y_value = ax.get_ylim()[1]  # Obtener el valor máximo actual del eje y
    ax.set_yticks(range(0, int(max_y_value) + 5, 5))  # Definir los ticks de 5 en 5

# Eliminar gráficos vacíos si hay más subplots que columnas en el DataFrame
for i in range(index + 1, num_rows * cols_per_row):
    fig.delaxes(axes.flat[i])


plt.show()

# %% [markdown]
# # Train knight

# %%
data_train = pd.read_csv("subject/Train_knight.csv")
data_train.head()
# Out:
#    Sensitivity  Hability  Strength   Power  Agility  Dexterity  Awareness  \
# 0        11.80     17.26     75.26   431.9  0.09087    0.06232   0.028530
# 1        19.81     22.15    130.00  1260.0  0.09831    0.10270   0.147900
# 2        10.97     17.20     71.73   371.5  0.08915    0.11130   0.094570
# 3        11.62     18.18     76.38   408.8  0.11750    0.14830   0.102000
# 4        11.26     19.83     71.30   388.1  0.08511    0.04413   0.005067
#
#    Prescience  Reactivity  Midi-chlorien  ...  Evade   Stims  Sprint   Combo  \
# 0    0.016380      0.1847        0.06019  ...  24.49   86.00   562.0  0.1244
# 1    0.094980      0.1582        0.05395  ...  30.88  186.80  2398.0  0.1512
# 2    0.036130      0.1489        0.06640  ...  26.87   90.14   476.4  0.1391
# 3    0.055640      0.1957        0.07255  ...  25.40   88.14   528.1  0.1780
# 4    0.005664      0.1637        0.06343  ...  26.43   76.38   435.9  0.1108
#
# ...

# %%
# Numero de bins y columnas totales del DataFrame
n_bins = 40
num_columns = len(data_train.columns)

# Definir el número de columnas por fila
cols_per_row = 5

# Calcular el número total de filas necesarias (redondeando hacia arriba)
num_rows = math.ceil(num_columns / cols_per_row)

# Crear una figura y una cuadrícula de subplots usando plt.subplots()
fig, axes = plt.subplots(num_rows, cols_per_row, figsize=(25, 25))
fig.tight_layout(pad=5.0)  # Ajustar espacio entre gráficos

# Agrupar los datos por 'knight' y obtener un DataFrame por cada grupo
knights = data_train.groupby('knight')

for index, column in enumerate(data.columns):
    # Calcular la posición en la cuadrícula
    row = index // cols_per_row
    col = index % cols_per_row

    # Crear el histograma en la posición correspondiente
    ax = axes[row, col]

    if 'Sith' in knights.groups:
        data_sith = knights.get_group('Sith')[column]
        ax.hist(data_sith, bins=n_bins, color='red', alpha=0.5, label='Sith')
    if 'Jedi' in knights.groups:
        data_sith = knights.get_group('Jedi')[column]
        ax.hist(data_sith, bins=n_bins, color='blue', alpha=0.5, label='Jedi')
        
    # Ajustar el título y la leyenda
    ax.set_title(column)
    ax.legend(loc="upper right")
    
    # Ajustar el eje y para que los ticks vayan de 5 en 5, comenzando desde 0
    max_y_value = ax.get_ylim()[1]  # Obtener el valor máximo actual del eje y
    ax.set_yticks(range(0, int(max_y_value) + 5, 5))  # Definir los ticks de 5 en 5

# Eliminar gráficos vacíos si hay más subplots que columnas en el DataFrame
for i in range(index + 1, num_rows * cols_per_row):
    fig.delaxes(axes.flat[i])
    
plt.show()
